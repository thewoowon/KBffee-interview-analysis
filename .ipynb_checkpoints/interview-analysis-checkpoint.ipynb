# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/kbffee-interview-analysis/interview.csv

# %%
# data load
df = pd.read_csv('/kaggle/input/kbffee-interview-analysis/interview.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 21 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   타임스탬프                                                                                              38 non-null     object
#  1   사내 카페를 주당 몇 회 이상 이용하시나요?                                                                           38 non-null     object
#  2   이용하지 않는 이유가 있다면 무엇일까요?                                                                             0 non-null      float64
#  3   본인이 생각하시는 사내 카페를 이용하는 이유를 선택해주세요 (복수응답 가능)                                                         38 non-null     object
#  4   (사내 카페 제외) 평소 포인트나 쿠폰 적립을 신경써서 관리하는 편이신가요?                                                         38 non-null     object
#  5   (사내 카페에서) 쿠폰 적립을 매번 하는 편이신가요?                                                                      38 non-null     object
#  6   쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?                                                                  12 non-null     object
#  7   쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요                                                                  12 non-null     object
#  8   현재 사내 카페에서 쿠폰 적립을 할 때 어떤 점이 불편하다고 생각하시나요?                                                          12 non-null     object
#  9   어떤 상황일 때 적립을 하지 않으셨나요?                                                                             14 non-null     object
#  10  쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요.1                                                                14 non-null     object
#  11  쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?.1                                                                14 non-null     object
#  12  적립을 하는 경우와 하지 않는 경우의 차이는 무엇이었나요?                                                                   6 non-null      object
#  13  쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요.2                                                                6 non-null      object
#  14  적립을 하지 않는 이유는 무엇인가요?                                                                               4 non-null      object
#  15  어떤 경우에 적립을 하시나요?                                                                                   4 non-null      object
#  16  적립을 하지 않는 이유는 무엇인가요?.1                                                                             2 non-null      object
#  17  사내 카페가 아닌 다른 곳에서는 적립을 챙기신다면, 이유는 무엇이라고 생각하시나요?                                                     2 non-null      object
#  18  현재 사내 카페의 쿠폰 적립과 관련하여 어떤 점이 바뀌면 적립을 더 하고 싶어질 것 같으신가요?                                              38 non-null     object
#  19  🙇🏻‍♂️여기까지 답변해주셔서 정말 감사드립니다!
# 현재 사내 카페의 쿠폰 적립 방법 또는 모든 것에 대해 자유로운 의견 부탁드립니다. 불편한 점 또는 아이디어 모두 환영입니다  24 non-null     object
#  20  추첨으로 무료 음료 쿠폰을 한 잔 더 받고싶으시다면 핸드폰 번호를 입력해주세요!
# *상품 전달 후 개인정보는 모두 폐기됩니다.
# *기호없이 숫자로만 입력해주세요.           28 non-null     object
# dtypes: float64(1), object(20)
# memory usage: 6.4+ KB
# None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 범주형 변수 고유값 확인하기 -> but 유효하지 않음...
categorical_columns = df.select_dtypes(include=['object']).columns

# 출력할 수 있지만 모든 질문지는 범주형이므로 의미가 없음.

# %% [markdown]
# ## 질문 확인하기 -> 컬럼 확인하기
#
# 질문이 즉 컬럼이 되었기 때문에 사용가능한 객관식 선택형 질문과 주관식 서술형 질문을 분류한다.
#
# ### 질문의 종류
#
# 1. 객관식 선택형
# 2. 객관식 다지선다형
# 3. 주관식 서술형

# %%
columns = df.columns
print(columns)
# Out:
# Index(['타임스탬프', '사내 카페를 주당 몇 회 이상 이용하시나요?', '이용하지 않는 이유가 있다면 무엇일까요?',
#        '본인이 생각하시는 사내 카페를 이용하는 이유를 선택해주세요 (복수응답 가능)',
#        '(사내 카페 제외) 평소 포인트나 쿠폰 적립을 신경써서 관리하는 편이신가요?',
#        '(사내 카페에서) 쿠폰 적립을 매번 하는 편이신가요?', '쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?',
#        '쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요',
#        '현재 사내 카페에서 쿠폰 적립을 할 때 어떤 점이 불편하다고 생각하시나요?', '어떤 상황일 때 적립을 하지 않으셨나요?',
#        '쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요.1',
#        '쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?.1',
#        '적립을 하는 경우와 하지 않는 경우의 차이는 무엇이었나요?',
#        '쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요.2', '적립을 하지 않는 이유는 무엇인가요?',
#        '어떤 경우에 적립을 하시나요?', '적립을 하지 않는 이유는 무엇인가요?.1',
#        '사내 카페가 아닌 다른 곳에서는 적립을 챙기신다면, 이유는 무엇이라고 생각하시나요?',
#        '현재 사내 카페의 쿠폰 적립과 관련하여 어떤 점이 바뀌면 적립을 더 하고 싶어질 것 같으신가요?',
#        '🙇🏻‍♂️여기까지 답변해주셔서 정말 감사드립니다!\n현재 사내 카페의 쿠폰 적립 방법 또는 모든 것에 대해 자유로운 의견 부탁드립니다. 불편한 점 또는 아이디어 모두 환영입니다',
#        '추첨으로 무료 음료 쿠폰을 한 잔 더 받고싶으시다면 핸드폰 번호를 입력해주세요!\n*상품 전달 후 개인정보는 모두 폐기됩니다.\n*기호없이 숫자로만 입력해주세요.'],
#       dtype='object')

# %% [markdown]
# ## 컬럼 리스트
#
# 1. 타임스탬프
# 2. 사내 카페를 주당 몇 회 이상 이용하시나요?
# 3. 이용하지 않는 이유가 있다면 무엇일까요?
# 4. 본인이 생각하시는 사내 카페를 이용하는 이유를 선택해주세요 (복수응답 가능)
# 5. (사내 카페 제외) 평소 포인트나 쿠폰 적립을 신경써서 관리하는 편이신가요?
# 6. (사내 카페에서) 쿠폰 적립을 매번 하는 편이신가요?
# 7. 쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?
# 8. 쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요
# 9. 현재 사내 카페에서 쿠폰 적립을 할 때 어떤 점이 불편하다고 생각하시나요?
# 10. 어떤 상황일 때 적립을 하지 않으셨나요?
# 11. 쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요
# 12. 쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?
# 13. 적립을 하는 경우와 하지 않는 경우의 차이는 무엇이었나요?
# 14. 쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요
# 15. 적립을 하지 않는 이유는 무엇인가요?
# 16. 어떤 경우에 적립을 하시나요?
# 17. 적립을 하지 않는 이유는 무엇인가요?
# 18. 사내 카페가 아닌 다른 곳에서는 적립을 챙기신다면, 이유는 무엇이라고 생각하시나요?
# 19. 현재 사내 카페의 쿠폰 적립과 관련하여 어떤 점이 바뀌면 적립을 더 하고 싶어질 것 같으신가요?
# 20. 🙇🏻‍♂️여기까지 답변해주셔서 정말 감사드립니다! 현재 사내 카페의 쿠폰 적립 방법 또는 모든 것에 대해 자유로운 의견 부탁드립니다. 불편한 점 또는 아이디어 모두 환영입니다
# 21. 추첨으로 무료 음료 쿠폰을 한 잔 더 받고싶으시다면 핸드폰 번호를 입력해주세요!

# %% [markdown]
# ## 컬럼 분류하기
#
# ### 타임스탬프
# 1. 타임스탬프
#
# ### 객관식 선택형
# 2. 사내 카페를 주당 몇 회 이상 이용하시나요?
# 3. 이용하지 않는 이유가 있다면 무엇일까요?
# 5. (사내 카페 제외) 평소 포인트나 쿠폰 적립을 신경써서 관리하는 편이신가요?
# 6. (사내 카페에서) 쿠폰 적립을 매번 하는 편이신가요?
#
# ### 객관식 다지선다형
# 4. 본인이 생각하시는 사내 카페를 이용하는 이유를 선택해주세요 (복수응답 가능)
#
# ### 주관식 서술형
# 7. 쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?
# 8. 쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요
# 9. 현재 사내 카페에서 쿠폰 적립을 할 때 어떤 점이 불편하다고 생각하시나요?
# 10. 어떤 상황일 때 적립을 하지 않으셨나요?
# 11. 쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요
# 12. 쿠폰 적립 시 내 쿠폰이 어디에 있는 지 어떻게 찾으시나요?
# 13. 적립을 하는 경우와 하지 않는 경우의 차이는 무엇이었나요?
# 14. 쿠폰을 적립하려 할 때 곤란했던 적이 있으셨다면 말씀해주세요
# 15. 적립을 하지 않는 이유는 무엇인가요?
# 16. 어떤 경우에 적립을 하시나요?
# 17. 적립을 하지 않는 이유는 무엇인가요?
# 18. 사내 카페가 아닌 다른 곳에서는 적립을 챙기신다면, 이유는 무엇이라고 생각하시나요?
# 19. 현재 사내 카페의 쿠폰 적립과 관련하여 어떤 점이 바뀌면 적립을 더 하고 싶어질 것 같으신가요?
# 20. 🙇🏻‍♂️여기까지 답변해주셔서 정말 감사드립니다! 현재 사내 카페의 쿠폰 적립 방법 또는 모든 것에 대해 자유로운 의견 부탁드립니다. 불편한 점 또는 아이디어 모두 환영입니다
# 21. 추첨으로 무료 음료 쿠폰을 한 잔 더 받고싶으시다면 핸드폰 번호를 입력해주세요!

# %% [markdown]
# ## 컬럼 정리하기
#
# 1번 인덱스에서 5번 인덱스까지의 컬러만을 추출해야한다.

# %%
# 타임스탬프 삭제, 객관식 질문만 추출
df = df.iloc[:,1:6]

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    사내 카페를 주당 몇 회 이상 이용하시나요?  이용하지 않는 이유가 있다면 무엇일까요?  \
# 0                     3회 이상                     NaN
# 1                     3회 이상                     NaN
# 2                        매일                     NaN
# 3                        매일                     NaN
# 4                     2회 이상                     NaN
# 5                     3회 이상                     NaN
# 6                     3회 이상                     NaN
# 7                     4회 이상                     NaN
# 8                     3회 이상                     NaN
# 9                     2회 이상                     NaN
# 10                    4회 이상                     NaN
# 11                    2회 이상                     NaN
# 12                       매일                     NaN
# 13                    3회 이상                     NaN
# 14                    2회 이상                     NaN
# 15                    2회 이상                     NaN
# 16                    1회 이상                     NaN
# 17                    3회 이상                     NaN
# 18                    1회 이상                     NaN
# 19                    1회 이상                     NaN
# 20                    1회 이상                     NaN
# 21                    1회 이상                     NaN
# 22                    1회 이상                     NaN
# 23                    4회 이상                     NaN
# 24                    4회 이상                     NaN
# 25                       매일                     NaN
# 26                    3회 이상                     NaN
# 27                       매일                     NaN
# 28                    4회 이상                     NaN
# 29                       매일                     NaN
# 30                       매일                     NaN
# 31                    4회 이상                     NaN
# 32                    2회 이상                     NaN
# 33                    1회 이상                     NaN
# 34                    4회 이상                     NaN
# 35                    3회 이상                     NaN
# 36                       매일                     NaN
# 37                       매일                     NaN
#
#    본인이 생각하시는 사내 카페를 이용하는 이유를 선택해주세요 (복수응답 가능)  \
# 0                                      가격;접근성
# 1                                      가격;접근성
# 2                                         접근성
# 3                          가격;접근성;쿠폰 적립;시설편의성
# 4                                         접근성
# 5                                      가격;접근성
# 6                                  가격;접근성;커피맛
# 7                                   접근성;쿠폰 적립
# 8                            가격;접근성;커피맛;쿠폰 적립
# 9                                         접근성
# 10                                 가격;접근성;커피맛
# 11                                        접근성
# 12                                        접근성
# 13                                         가격
# 14                                         가격
# 15                           가격;접근성;커피맛;시설편의성
# 16                                     가격;접근성
# 17                                        접근성
# 18                                        접근성
# 19                                     가격;접근성
# 20                                        접근성
# 21                                        접근성
# 22                                  접근성;쿠폰 적립
# 23                                        접근성
# 24                                     가격;접근성
# 25                                  접근성;쿠폰 적립
# 26                                         가격
# 27                                        접근성
# 28                                        접근성
# 29                                   가격;쿠폰 적립
# 30                               가격;접근성;쿠폰 적립
# 31                                        접근성
# 32                                     가격;접근성
# 33                                  접근성;시설편의성
# 34                                     가격;접근성
# 35                                        접근성
# 36                                  접근성;쿠폰 적립
# 37                               가격;접근성;쿠폰 적립
#
#    (사내 카페 제외) 평소 포인트나 쿠폰 적립을 신경써서 관리하는 편이신가요? (사내 카페에서) 쿠폰 적립을 매번 하는 편이신가요?
# 0                                      그렇지 않다                     거의 하지 않는다
# 1                                         그렇다                         매번 한다
# 2                                      매우 그렇다                         매번 한다
# 3                                          보통                         매번 한다
# 4                                          보통            가끔 한두번은 하지 않는 것 같다
# 5                                         그렇다            가끔 한두번은 하지 않는 것 같다
# 6                                         그렇다                     거의 하지 않는다
# 7                                         그렇다                         매번 한다
# 8                                          보통             할 때도 있고 안 할 때도 있다
# 9                                      그렇지 않다                     거의 하지 않는다
# 10                                     그렇지 않다                     거의 하지 않는다
# 11                                         보통                         매번 한다
# 12                                     매우 그렇다                         매번 한다
# 13                                        그렇다            가끔 한두번은 하지 않는 것 같다
# 14                                     매우 그렇다                         매번 한다
# 15                                        그렇다            가끔 한두번은 하지 않는 것 같다
# 16                                        그렇다             할 때도 있고 안 할 때도 있다
# 17                                        그렇다             할 때도 있고 안 할 때도 있다
# 18                                     그렇지 않다             할 때도 있고 안 할 때도 있다
# 19                                         보통             할 때도 있고 안 할 때도 있다
# 20                                        그렇다            가끔 한두번은 하지 않는 것 같다
# 21                                        그렇다            가끔 한두번은 하지 않는 것 같다
# 22                                     그렇지 않다                     아예 하지 않는다
# 23                                         보통            가끔 한두번은 하지 않는 것 같다
# 24                                     매우 그렇다            가끔 한두번은 하지 않는 것 같다
# 25                                     매우 그렇다            가끔 한두번은 하지 않는 것 같다
# 26                                        그렇다            가끔 한두번은 하지 않는 것 같다
# 27                                         보통            가끔 한두번은 하지 않는 것 같다
# 28                                        그렇다                         매번 한다
# 29                                     매우 그렇다                         매번 한다
# 30                                        그렇다            가끔 한두번은 하지 않는 것 같다
# 31                                        그렇다                         매번 한다
# 32                                         보통            가끔 한두번은 하지 않는 것 같다
# 33                                  매우 그렇지 않다                     아예 하지 않는다
# 34                                     매우 그렇다                         매번 한다
# 35                                         보통             할 때도 있고 안 할 때도 있다
# 36                                     매우 그렇다                         매번 한다
# 37                                         보통            가끔 한두번은 하지 않는 것 같다

# %% [markdown]
# ## 컬럼명 정하기
#
# 질문으로 이루어진 컬럼명을 단순한 컬럼명으로 치환한다.
#
# 컬럼명은 다음과 같이 매핑한다.
#
# - 사내 카페를 주당 몇 회 이상 이용하시나요?	 -> 주당_카페_방문횟수
# - 이용하지 않는 이유가 있다면 무엇일까요? -> 결측
# - 본인이 생각하시는 사내 카페를 이용하는 이유를 선택해주세요 (복수응답 가능) -> 카페_선택_이유
# - (사내 카페 제외) 평소 포인트나 쿠폰 적립을 신경써서 관리하는 편이신가요? -> 포인트_쿠폰_관리
# - (사내 카페에서) 쿠폰 적립을 매번 하는 편이신가요? -> 적립_빈도

# %%
new_column_names = ["주당_카페_방문횟수", "결측", "카페_선택_이유", "포인트_쿠폰_관리","적립_빈도"]  # 원하는 컬럼명으로 변경
df.columns = new_column_names

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    주당_카페_방문횟수  결측            카페_선택_이유  포인트_쿠폰_관리               적립_빈도
# 0       3회 이상 NaN              가격;접근성     그렇지 않다           거의 하지 않는다
# 1       3회 이상 NaN              가격;접근성        그렇다               매번 한다
# 2          매일 NaN                 접근성     매우 그렇다               매번 한다
# 3          매일 NaN  가격;접근성;쿠폰 적립;시설편의성         보통               매번 한다
# 4       2회 이상 NaN                 접근성         보통  가끔 한두번은 하지 않는 것 같다
# 5       3회 이상 NaN              가격;접근성        그렇다  가끔 한두번은 하지 않는 것 같다
# 6       3회 이상 NaN          가격;접근성;커피맛        그렇다           거의 하지 않는다
# 7       4회 이상 NaN           접근성;쿠폰 적립        그렇다               매번 한다
# 8       3회 이상 NaN    가격;접근성;커피맛;쿠폰 적립         보통   할 때도 있고 안 할 때도 있다
# 9       2회 이상 NaN                 접근성     그렇지 않다           거의 하지 않는다
# 10      4회 이상 NaN          가격;접근성;커피맛     그렇지 않다           거의 하지 않는다
# 11      2회 이상 NaN                 접근성         보통               매번 한다
# 12         매일 NaN                 접근성     매우 그렇다               매번 한다
# 13      3회 이상 NaN                  가격        그렇다  가끔 한두번은 하지 않는 것 같다
# 14      2회 이상 NaN                  가격     매우 그렇다               매번 한다
# 15      2회 이상 NaN    가격;접근성;커피맛;시설편의성        그렇다  가끔 한두번은 하지 않는 것 같다
# 16      1회 이상 NaN              가격;접근성        그렇다   할 때도 있고 안 할 때도 있다
# 17      3회 이상 NaN                 접근성        그렇다   할 때도 있고 안 할 때도 있다
# 18      1회 이상 NaN                 접근성     그렇지 않다   할 때도 있고 안 할 때도 있다
# 19      1회 이상 NaN              가격;접근성         보통   할 때도 있고 안 할 때도 있다
# 20      1회 이상 NaN                 접근성        그렇다  가끔 한두번은 하지 않는 것 같다
# 21      1회 이상 NaN                 접근성        그렇다  가끔 한두번은 하지 않는 것 같다
# 22      1회 이상 NaN           접근성;쿠폰 적립     그렇지 않다           아예 하지 않는다
# 23      4회 이상 NaN                 접근성         보통  가끔 한두번은 하지 않는 것 같다
# 24      4회 이상 NaN              가격;접근성     매우 그렇다  가끔 한두번은 하지 않는 것 같다
# 25         매일 NaN           접근성;쿠폰 적립     매우 그렇다  가끔 한두번은 하지 않는 것 같다
# 26      3회 이상 NaN                  가격        그렇다  가끔 한두번은 하지 않는 것 같다
# 27         매일 NaN                 접근성         보통  가끔 한두번은 하지 않는 것 같다
# 28      4회 이상 NaN                 접근성        그렇다               매번 한다
# 29         매일 NaN            가격;쿠폰 적립     매우 그렇다               매번 한다
# 30         매일 NaN        가격;접근성;쿠폰 적립        그렇다  가끔 한두번은 하지 않는 것 같다
# 31      4회 이상 NaN                 접근성        그렇다               매번 한다
# 32      2회 이상 NaN              가격;접근성         보통  가끔 한두번은 하지 않는 것 같다
# 33      1회 이상 NaN           접근성;시설편의성  매우 그렇지 않다           아예 하지 않는다
# 34      4회 이상 NaN              가격;접근성     매우 그렇다               매번 한다
# 35      3회 이상 NaN                 접근성         보통   할 때도 있고 안 할 때도 있다
# 36         매일 NaN           접근성;쿠폰 적립     매우 그렇다               매번 한다
# 37         매일 NaN        가격;접근성;쿠폰 적립         보통  가끔 한두번은 하지 않는 것 같다

# %%
# 결측 컬럼 우선 제거
df = df.drop(df.columns[1], axis=1)

# %%
df
# Out:
#    주당_카페_방문횟수            카페_선택_이유  포인트_쿠폰_관리               적립_빈도
# 0       3회 이상              가격;접근성     그렇지 않다           거의 하지 않는다
# 1       3회 이상              가격;접근성        그렇다               매번 한다
# 2          매일                 접근성     매우 그렇다               매번 한다
# 3          매일  가격;접근성;쿠폰 적립;시설편의성         보통               매번 한다
# 4       2회 이상                 접근성         보통  가끔 한두번은 하지 않는 것 같다
# 5       3회 이상              가격;접근성        그렇다  가끔 한두번은 하지 않는 것 같다
# 6       3회 이상          가격;접근성;커피맛        그렇다           거의 하지 않는다
# 7       4회 이상           접근성;쿠폰 적립        그렇다               매번 한다
# 8       3회 이상    가격;접근성;커피맛;쿠폰 적립         보통   할 때도 있고 안 할 때도 있다
# 9       2회 이상                 접근성     그렇지 않다           거의 하지 않는다
# 10      4회 이상          가격;접근성;커피맛     그렇지 않다           거의 하지 않는다
# 11      2회 이상                 접근성         보통               매번 한다
# 12         매일                 접근성     매우 그렇다               매번 한다
# 13      3회 이상                  가격        그렇다  가끔 한두번은 하지 않는 것 같다
# 14      2회 이상                  가격     매우 그렇다               매번 한다
# 15      2회 이상    가격;접근성;커피맛;시설편의성        그렇다  가끔 한두번은 하지 않는 것 같다
# 16      1회 이상              가격;접근성        그렇다   할 때도 있고 안 할 때도 있다
# 17      3회 이상                 접근성        그렇다   할 때도 있고 안 할 때도 있다
# 18      1회 이상                 접근성     그렇지 않다   할 때도 있고 안 할 때도 있다
# 19      1회 이상              가격;접근성         보통   할 때도 있고 안 할 때도 있다
# 20      1회 이상                 접근성        그렇다  가끔 한두번은 하지 않는 것 같다
# 21      1회 이상                 접근성        그렇다  가끔 한두번은 하지 않는 것 같다
# 22      1회 이상           접근성;쿠폰 적립     그렇지 않다           아예 하지 않는다
# 23      4회 이상                 접근성         보통  가끔 한두번은 하지 않는 것 같다
# 24      4회 이상              가격;접근성     매우 그렇다  가끔 한두번은 하지 않는 것 같다
# 25         매일           접근성;쿠폰 적립     매우 그렇다  가끔 한두번은 하지 않는 것 같다
# 26      3회 이상                  가격        그렇다  가끔 한두번은 하지 않는 것 같다
# 27         매일                 접근성         보통  가끔 한두번은 하지 않는 것 같다
# 28      4회 이상                 접근성        그렇다               매번 한다
# 29         매일            가격;쿠폰 적립     매우 그렇다               매번 한다
# 30         매일        가격;접근성;쿠폰 적립        그렇다  가끔 한두번은 하지 않는 것 같다
# 31      4회 이상                 접근성        그렇다               매번 한다
# 32      2회 이상              가격;접근성         보통  가끔 한두번은 하지 않는 것 같다
# 33      1회 이상           접근성;시설편의성  매우 그렇지 않다           아예 하지 않는다
# 34      4회 이상              가격;접근성     매우 그렇다               매번 한다
# 35      3회 이상                 접근성         보통   할 때도 있고 안 할 때도 있다
# 36         매일           접근성;쿠폰 적립     매우 그렇다               매번 한다
# 37         매일        가격;접근성;쿠폰 적립         보통  가끔 한두번은 하지 않는 것 같다

# %%
# 데이터 shape 확인
df.shape
# Out:
# (38, 4)

# %%
# 결측치 확인하기
print(df.isnull().sum())

# 범주형 고유값 출력
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f"\n => [{col}]의 고유값 분포")
    print(df[col].value_counts())
# Out:
# 주당_카페_방문횟수    0
# 카페_선택_이유      0
# 포인트_쿠폰_관리     0
# 적립_빈도         0
# dtype: int64
#
#  => [주당_카페_방문횟수]의 고유값 분포
# 주당_카페_방문횟수
# 3회 이상    9
# 매일       9
# 4회 이상    7
# 1회 이상    7
# 2회 이상    6
# Name: count, dtype: int64
#
#  => [카페_선택_이유]의 고유값 분포
# 카페_선택_이유
# 접근성                   14
# 가격;접근성                 8
# 접근성;쿠폰 적립              4
# 가격                     3
# 가격;접근성;커피맛             2
# 가격;접근성;쿠폰 적립           2
# 가격;접근성;쿠폰 적립;시설편의성     1
# 가격;접근성;커피맛;쿠폰 적립       1
# 가격;접근성;커피맛;시설편의성       1
# 가격;쿠폰 적립               1
# 접근성;시설편의성              1
# Name: count, dtype: int64
#
#  => [포인트_쿠폰_관리]의 고유값 분포
# 포인트_쿠폰_관리
# 그렇다          14
# 보통           10
# 매우 그렇다        8
# 그렇지 않다        5
# 매우 그렇지 않다     1
# Name: count, dtype: int64
#
#  => [적립_빈도]의 고유값 분포
# 적립_빈도
# 가끔 한두번은 하지 않는 것 같다    14
# 매번 한다                 12
# 할 때도 있고 안 할 때도 있다      6
# 거의 하지 않는다              4
# 아예 하지 않는다              2
# Name: count, dtype: int64

# %% [markdown]
# 결측치는 확인되지 않는다.
# 객관식 다지선다형은 세미콜론을 활용해 분리가 가능한 것으로 보인다.

# %%
# 첫 3줄 출력
df.head(3)
# Out:
#   주당_카페_방문횟수 카페_선택_이유 포인트_쿠폰_관리      적립_빈도
# 0      3회 이상   가격;접근성    그렇지 않다  거의 하지 않는다
# 1      3회 이상   가격;접근성       그렇다      매번 한다
# 2         매일      접근성    매우 그렇다      매번 한다

# %%
# 마지막 3줄 출력
df.tail(3)
# Out:
#    주당_카페_방문횟수      카페_선택_이유 포인트_쿠폰_관리               적립_빈도
# 35      3회 이상           접근성        보통   할 때도 있고 안 할 때도 있다
# 36         매일     접근성;쿠폰 적립    매우 그렇다               매번 한다
# 37         매일  가격;접근성;쿠폰 적립        보통  가끔 한두번은 하지 않는 것 같다

# %% [markdown]
# ## Feature Engineering
#
# 주당_카페_방문횟수, 포인트_쿠폰_관리, 적립_빈도 컬럼은 객관식 선택형으로 최대 5개정도의 범주로 보아 레이블인코딩이 가능해보인다.
# 하지만 카페_선택_이유 컬럼의 경우 다지선다형으로 원핫인코딩으로 각각의 선택지를 더미변수로 전환해 해결해야한다.

# %%
# 카페_선택_이유 컬럼 변환
df = df.join(df['카페_선택_이유'].str.get_dummies(sep=";")).drop(columns=['카페_선택_이유'])

# %%
# 주당_카페_방문횟수, 포인트_쿠폰_관리, 적립_빈도 레이블인코딩
df["주당_카페_방문횟수"] = df["주당_카페_방문횟수"].astype("category").cat.codes
df["포인트_쿠폰_관리"] = df["포인트_쿠폰_관리"].astype("category").cat.codes
df["적립_빈도"] = df["적립_빈도"].astype("category").cat.codes

# %%
df
# Out:
#     주당_카페_방문횟수  포인트_쿠폰_관리  적립_빈도  가격  시설편의성  접근성  커피맛  쿠폰 적립
# 0            2          1      1   1      0    1    0      0
# 1            2          0      2   1      0    1    0      0
# 2            4          2      2   0      0    1    0      0
# 3            4          4      2   1      1    1    0      1
# 4            1          4      0   0      0    1    0      0
# 5            2          0      0   1      0    1    0      0
# 6            2          0      1   1      0    1    1      0
# 7            3          0      2   0      0    1    0      1
# 8            2          4      4   1      0    1    1      1
# 9            1          1      1   0      0    1    0      0
# 10           3          1      1   1      0    1    1      0
# 11           1          4      2   0      0    1    0      0
# 12           4          2      2   0      0    1    0      0
# 13           2          0      0   1      0    0    0      0
# 14           1          2      2   1      0    0    0      0
# 15           1          0      0   1      1    1    1      0
# 16           0          0      4   1      0    1    0      0
# 17           2          0      4   0      0    1    0      0
# 18           0          1      4   0      0    1    0      0
# 19           0          4      4   1      0    1    0      0
# 20           0          0      0   0      0    1    0      0
# 21           0          0      0   0      0    1    0      0
# 22           0          1      3   0      0    1    0      1
# 23           3          4      0   0      0    1    0      0
# 24           3          2      0   1      0    1    0      0
# 25           4          2      0   0      0    1    0      1
# 26           2          0      0   1      0    0    0      0
# 27           4          4      0   0      0    1    0      0
# 28           3          0      2   0      0    1    0      0
# 29           4          2      2   1      0    0    0      1
# 30           4          0      0   1      0    1    0      1
# 31           3          0      2   0      0    1    0      0
# 32           1          4      0   1      0    1    0      0
# 33           0          3      3   0      1    1    0      0
# 34           3          2      2   1      0    1    0      0
# 35           2          4      4   0      0    1    0      0
# 36           4          2      2   0      0    1    0      1
# 37           4          4      0   1      0    1    0      1
